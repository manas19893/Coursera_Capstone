# %%
import numpy as np 
import pandas as pd 
from bs4 import BeautifulSoup
import requests

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
content = BeautifulSoup(requests.get(url).content, 'lxml')

# %%
table = content.find('table')
td = table.find_all('td')
postcode = []
borough = []
neighbourhood = []

# %%
for i in range(0, len(td), 3):
    postcode.append(td[i].text.strip())
    borough.append(td[i+1].text.strip())
    neighbourhood.append(td[i+2].text.strip())

# %%
#dataframe containig 3 columns
df = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()
df.columns = ['Postal Code', 'Borough', 'Neighborhood']

# %%
#Removing not assigned
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.dropna(subset=['Borough'], inplace=True)

# %%
#Neighborhood same as Borough
df['Neighborhood'].replace('Not assigned', "Queen's Park", inplace=True)

# %%
df = wiki_df.groupby(['Postal Code', 'Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.columns = ['Postal Code', 'Borough', 'Neighborhood']
df.head(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a47ff9b6c640> in <module>
# ----> 1 df = wiki_df.groupby(['Postal Code', 'Borough'])['Neighborhood'].apply(', '.join).reset_index()
#       2 df.columns = ['Postal Code', 'Borough', 'Neighborhood']
#       3 df.head(12)
#
# NameError: name 'wiki_df' is not defined
